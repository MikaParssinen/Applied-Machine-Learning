# %% [markdown]
# # *Libraries*

# %%
import os
import tensorflow as tf
from keras.src.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # *Load data*

# %%
def load() :
    train_dir = "/Users/mika/Applied-Machine-Learning/Project/dataset/CNN_Input/train"
    test_dir = "/Users/mika/Applied-Machine-Learning/Project/dataset/CNN_Input/test" 

    # Load train data
    train_data = tf.keras.preprocessing.image_dataset_from_directory(
        train_dir,
        image_size=(150, 150),
        batch_size=32,
        label_mode='categorical'
    )

    # Load test data
    test_data = tf.keras.preprocessing.image_dataset_from_directory(
        test_dir,
        image_size=(150, 150),
        batch_size=32,
        label_mode='categorical'  # Categorical labels for multi-class classification
    )
    
    return test_data, train_data

# %% [markdown]
# # *Plot 8 images*

# %%
def plot_img(train_data) :
    class_names = train_data.class_names  
    plt.figure(figsize=(8, 5)) 
    for images, labels in train_data.take(1):  # Take one batch from the dataset
        for i in range(8):
            ax = plt.subplot(2, 4, i + 1) 
            plt.imshow(images[i].numpy().astype("uint8"))
            plt.title(class_names[np.argmax(labels[i].numpy())])
            plt.axis("off")
        plt.subplots_adjust(hspace=0, wspace=0)
        plt.show()

# %% [markdown]
# # *Data preparation*

# %%
def normalize_img(train_data, test_data):
   
    def normalize(image, label):
        image = image / 255.0  
        return image, label  
        
    # Normalization to both train and test datasets
    train_data_norm = train_data.map(normalize)
    test_data_norm = test_data.map(normalize)

    return test_data_norm, train_data_norm

# %% [markdown]
# # *Build and Compile CNN*

# %%
# Build the CNN model for multi-class classification
def build_cnn_model():
    model = models.Sequential([
        layers.InputLayer(shape=(150, 150, 3)),  # Input shape (150x150x3)
        
        # Convolutional layers with max pooling
        layers.Conv2D(32, (3, 3), activation='relu', padding='same', strides=(2, 2)),
        layers.MaxPooling2D((2, 2)),
        
        layers.Conv2D(64, (3, 3), activation='relu', padding='same', strides=(2, 2)),
        layers.MaxPooling2D((2, 2)),
        
        layers.Conv2D(128, (3, 3), activation='relu', padding='same', strides=(2, 2)),
        layers.MaxPooling2D((2, 2)),
        
        # Flatten the output and pass through dense layers
        layers.Flatten(),
        layers.Dense(128, activation='relu'),
        layers.Dense(4, activation='softmax')  # 4 output units, one for each class (good, bad, contaminated, etc.)
    ])
    
    # Compile the model with sparse categorical crossentropy loss
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model

# %% [markdown]
# # *Train model*

# %%
# Stop training early if no improvement in validation loss for 5 epochs

def train_model(model, train_data_norm, test_data_norm):

    callbacks = [  
        # Stop training early if no improvement in validation loss for 5 epochs
         EarlyStopping(
            monitor='val_loss', 
            patience=5, 
            restore_best_weights=True
        ),
        # Reduce learning rate if validation loss plateaus
        ReduceLROnPlateau(
            monitor='val_loss', 
            factor=0.2,
            patience=3 
        )
    ]
    
    history = model.fit(
        train_data_norm,
        epochs=70,
        validation_data=test_data_norm,
        callbacks=callbacks
    )
    return history

# %% [markdown]
# # *Plotting Training and Validation Figures*

# %%
def plot_metrics(history): # Insert parameter name

    # Plot traning and validation loss
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.legend()

    # Plot traning and validation accuracy
    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.legend()
    plt.show()

# %%
test_data, train_data = load()
plot_img(train_data)

test_data_norm, train_data_norm = normalize_img(train_data, test_data)
model = build_cnn_model()
model.summary()
history = train_model(model, train_data_norm, test_data_norm)
plot_metrics(history)

test_loss, test_accuracy = model.evaluate(test_data_norm)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# Found 83 files belonging to 4 classes.
# Found 83 files belonging to 4 classes.
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_18 (Conv2D)              │ (None, 75, 75, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_18 (MaxPooling2D) │ (None, 37, 37, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_19 (Conv2D)              │ (None, 19, 19, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_19 (MaxPooling2D) │ (None, 9, 9, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_20 (Conv2D)              │ (None, 5, 5, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_20 (MaxPooling2D) │ (None, 2, 2, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_6 (Flatten)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 128)            │        65,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 159,428 (622.77 KB)
#  Trainable params: 159,428 (622.77 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 331ms/step - accuracy: 0.2377 - loss: 1.4012 - val_accuracy: 0.2530 - val_loss: 1.3905 - learning_rate: 0.0010
# Epoch 2/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 327ms/step - accuracy: 0.2554 - loss: 1.3924 - val_accuracy: 0.4217 - val_loss: 1.3769 - learning_rate: 0.0010
# Epoch 3/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 343ms/step - accuracy: 0.3874 - loss: 1.3766 - val_accuracy: 0.2651 - val_loss: 1.3736 - learning_rate: 0.0010
# Epoch 4/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 305ms/step - accuracy: 0.2110 - loss: 1.3934 - val_accuracy: 0.2651 - val_loss: 1.3669 - learning_rate: 0.0010
# Epoch 5/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 323ms/step - accuracy: 0.2536 - loss: 1.3686 - val_accuracy: 0.2651 - val_loss: 1.3598 - learning_rate: 0.0010
# Epoch 6/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 339ms/step - accuracy: 0.2614 - loss: 1.3604 - val_accuracy: 0.2651 - val_loss: 1.3489 - learning_rate: 0.0010
# Epoch 7/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 324ms/step - accuracy: 0.2575 - loss: 1.3506 - val_accuracy: 0.3735 - val_loss: 1.3296 - learning_rate: 0.0010
# Epoch 8/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 384ms/step - accuracy: 0.4008 - loss: 1.3397 - val_accuracy: 0.5181 - val_loss: 1.3037 - learning_rate: 0.0010
# Epoch 9/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 351ms/step - accuracy: 0.5665 - loss: 1.3023 - val_accuracy: 0.6506 - val_loss: 1.2680 - learning_rate: 0.0010
# Epoch 10/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 316ms/step - accuracy: 0.6311 - loss: 1.2585 - val_accuracy: 0.5422 - val_loss: 1.2180 - learning_rate: 0.0010
# Epoch 11/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 374ms/step - accuracy: 0.6555 - loss: 1.2198 - val_accuracy: 0.7470 - val_loss: 1.1640 - learning_rate: 0.0010
# Epoch 12/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 350ms/step - accuracy: 0.6603 - loss: 1.1728 - val_accuracy: 0.6988 - val_loss: 1.1025 - learning_rate: 0.0010
# Epoch 13/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 302ms/step - accuracy: 0.5219 - loss: 1.1236 - val_accuracy: 0.7349 - val_loss: 1.0380 - learning_rate: 0.0010
# Epoch 14/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 313ms/step - accuracy: 0.6645 - loss: 1.1067 - val_accuracy: 0.6506 - val_loss: 1.0653 - learning_rate: 0.0010
# Epoch 15/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 305ms/step - accuracy: 0.5807 - loss: 1.0796 - val_accuracy: 0.8072 - val_loss: 0.9572 - learning_rate: 0.0010
# Epoch 16/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 309ms/step - accuracy: 0.6326 - loss: 0.9864 - val_accuracy: 0.6386 - val_loss: 0.9223 - learning_rate: 0.0010
# Epoch 17/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 306ms/step - accuracy: 0.7389 - loss: 0.8580 - val_accuracy: 0.8193 - val_loss: 0.8694 - learning_rate: 0.0010
# Epoch 18/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 304ms/step - accuracy: 0.7674 - loss: 0.8623 - val_accuracy: 0.7229 - val_loss: 0.7600 - learning_rate: 0.0010
# Epoch 19/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 309ms/step - accuracy: 0.7620 - loss: 0.7315 - val_accuracy: 0.6386 - val_loss: 0.7899 - learning_rate: 0.0010
# Epoch 20/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 314ms/step - accuracy: 0.6559 - loss: 0.7779 - val_accuracy: 0.7349 - val_loss: 0.6649 - learning_rate: 0.0010
# Epoch 21/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 308ms/step - accuracy: 0.6495 - loss: 0.7031 - val_accuracy: 0.8313 - val_loss: 0.5578 - learning_rate: 0.0010
# Epoch 22/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 364ms/step - accuracy: 0.8060 - loss: 0.5918 - val_accuracy: 0.9036 - val_loss: 0.5112 - learning_rate: 0.0010
# Epoch 23/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 382ms/step - accuracy: 0.8592 - loss: 0.4982 - val_accuracy: 0.8072 - val_loss: 0.4716 - learning_rate: 0.0010
# Epoch 24/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 383ms/step - accuracy: 0.8177 - loss: 0.4536 - val_accuracy: 0.9277 - val_loss: 0.4133 - learning_rate: 0.0010
# Epoch 25/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 359ms/step - accuracy: 0.8965 - loss: 0.3796 - val_accuracy: 0.8554 - val_loss: 0.3908 - learning_rate: 0.0010
# Epoch 26/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 330ms/step - accuracy: 0.8457 - loss: 0.3867 - val_accuracy: 0.9157 - val_loss: 0.3124 - learning_rate: 0.0010
# Epoch 27/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 299ms/step - accuracy: 0.9127 - loss: 0.3415 - val_accuracy: 0.9398 - val_loss: 0.2707 - learning_rate: 0.0010
# Epoch 28/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 281ms/step - accuracy: 0.9344 - loss: 0.2537 - val_accuracy: 0.9157 - val_loss: 0.2478 - learning_rate: 0.0010
# Epoch 29/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 300ms/step - accuracy: 0.8872 - loss: 0.2790 - val_accuracy: 0.9759 - val_loss: 0.2157 - learning_rate: 0.0010
# Epoch 30/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 309ms/step - accuracy: 0.9461 - loss: 0.2467 - val_accuracy: 0.9518 - val_loss: 0.2095 - learning_rate: 0.0010
# Epoch 31/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 350ms/step - accuracy: 0.9503 - loss: 0.2279 - val_accuracy: 0.9036 - val_loss: 0.2133 - learning_rate: 0.0010
# Epoch 32/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 493ms/step - accuracy: 0.9248 - loss: 0.2467 - val_accuracy: 0.9639 - val_loss: 0.1788 - learning_rate: 0.0010
# Epoch 33/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 626ms/step - accuracy: 0.9546 - loss: 0.1870 - val_accuracy: 0.9277 - val_loss: 0.1907 - learning_rate: 0.0010
# Epoch 34/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 534ms/step - accuracy: 0.9425 - loss: 0.1781 - val_accuracy: 0.9759 - val_loss: 0.1450 - learning_rate: 0.0010
# Epoch 35/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 427ms/step - accuracy: 0.9564 - loss: 0.1726 - val_accuracy: 1.0000 - val_loss: 0.1075 - learning_rate: 0.0010
# Epoch 36/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 344ms/step - accuracy: 0.9880 - loss: 0.1247 - val_accuracy: 0.9880 - val_loss: 0.1052 - learning_rate: 0.0010
# Epoch 37/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 296ms/step - accuracy: 0.9823 - loss: 0.0965 - val_accuracy: 0.9398 - val_loss: 0.1479 - learning_rate: 0.0010
# Epoch 38/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 346ms/step - accuracy: 0.9503 - loss: 0.1557 - val_accuracy: 0.9880 - val_loss: 0.1161 - learning_rate: 0.0010
# Epoch 39/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 437ms/step - accuracy: 0.9741 - loss: 0.1325 - val_accuracy: 0.9518 - val_loss: 0.1295 - learning_rate: 0.0010
# Epoch 40/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 386ms/step - accuracy: 0.9564 - loss: 0.1193 - val_accuracy: 1.0000 - val_loss: 0.0875 - learning_rate: 2.0000e-04
# Epoch 41/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 359ms/step - accuracy: 1.0000 - loss: 0.0838 - val_accuracy: 1.0000 - val_loss: 0.0659 - learning_rate: 2.0000e-04
# Epoch 42/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 489ms/step - accuracy: 1.0000 - loss: 0.0676 - val_accuracy: 1.0000 - val_loss: 0.0784 - learning_rate: 2.0000e-04
# Epoch 43/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 447ms/step - accuracy: 1.0000 - loss: 0.0724 - val_accuracy: 1.0000 - val_loss: 0.0714 - learning_rate: 2.0000e-04
# Epoch 44/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 348ms/step - accuracy: 1.0000 - loss: 0.0684 - val_accuracy: 1.0000 - val_loss: 0.0633 - learning_rate: 2.0000e-04
# Epoch 45/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 291ms/step - accuracy: 1.0000 - loss: 0.0550 - val_accuracy: 1.0000 - val_loss: 0.0605 - learning_rate: 2.0000e-04
# Epoch 46/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 304ms/step - accuracy: 1.0000 - loss: 0.0584 - val_accuracy: 1.0000 - val_loss: 0.0570 - learning_rate: 2.0000e-04
# Epoch 47/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 325ms/step - accuracy: 1.0000 - loss: 0.0579 - val_accuracy: 1.0000 - val_loss: 0.0581 - learning_rate: 2.0000e-04
# Epoch 48/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 336ms/step - accuracy: 1.0000 - loss: 0.0578 - val_accuracy: 1.0000 - val_loss: 0.0525 - learning_rate: 2.0000e-04
# Epoch 49/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 329ms/step - accuracy: 1.0000 - loss: 0.0558 - val_accuracy: 1.0000 - val_loss: 0.0523 - learning_rate: 2.0000e-04
# Epoch 50/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 334ms/step - accuracy: 1.0000 - loss: 0.0582 - val_accuracy: 1.0000 - val_loss: 0.0512 - learning_rate: 2.0000e-04
# Epoch 51/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 337ms/step - accuracy: 1.0000 - loss: 0.0529 - val_accuracy: 1.0000 - val_loss: 0.0464 - learning_rate: 2.0000e-04
# Epoch 52/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 325ms/step - accuracy: 1.0000 - loss: 0.0440 - val_accuracy: 1.0000 - val_loss: 0.0466 - learning_rate: 2.0000e-04
# Epoch 53/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 321ms/step - accuracy: 1.0000 - loss: 0.0455 - val_accuracy: 1.0000 - val_loss: 0.0453 - learning_rate: 2.0000e-04
# Epoch 54/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 312ms/step - accuracy: 1.0000 - loss: 0.0429 - val_accuracy: 1.0000 - val_loss: 0.0432 - learning_rate: 2.0000e-04
# Epoch 55/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 306ms/step - accuracy: 1.0000 - loss: 0.0424 - val_accuracy: 1.0000 - val_loss: 0.0417 - learning_rate: 2.0000e-04
# Epoch 56/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 258ms/step - accuracy: 1.0000 - loss: 0.0441 - val_accuracy: 1.0000 - val_loss: 0.0410 - learning_rate: 2.0000e-04
# Epoch 57/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 309ms/step - accuracy: 1.0000 - loss: 0.0409 - val_accuracy: 1.0000 - val_loss: 0.0400 - learning_rate: 2.0000e-04
# Epoch 58/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 315ms/step - accuracy: 1.0000 - loss: 0.0391 - val_accuracy: 1.0000 - val_loss: 0.0390 - learning_rate: 2.0000e-04
# Epoch 59/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 317ms/step - accuracy: 1.0000 - loss: 0.0373 - val_accuracy: 1.0000 - val_loss: 0.0383 - learning_rate: 2.0000e-04
# Epoch 60/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 304ms/step - accuracy: 1.0000 - loss: 0.0334 - val_accuracy: 1.0000 - val_loss: 0.0369 - learning_rate: 2.0000e-04
# Epoch 61/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 287ms/step - accuracy: 1.0000 - loss: 0.0366 - val_accuracy: 1.0000 - val_loss: 0.0369 - learning_rate: 2.0000e-04
# Epoch 62/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 302ms/step - accuracy: 1.0000 - loss: 0.0354 - val_accuracy: 1.0000 - val_loss: 0.0351 - learning_rate: 2.0000e-04
# Epoch 63/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 301ms/step - accuracy: 1.0000 - loss: 0.0361 - val_accuracy: 1.0000 - val_loss: 0.0354 - learning_rate: 2.0000e-04
# Epoch 64/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 308ms/step - accuracy: 1.0000 - loss: 0.0354 - val_accuracy: 1.0000 - val_loss: 0.0337 - learning_rate: 2.0000e-04
# Epoch 65/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 276ms/step - accuracy: 1.0000 - loss: 0.0305 - val_accuracy: 1.0000 - val_loss: 0.0335 - learning_rate: 2.0000e-04
# Epoch 66/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 314ms/step - accuracy: 1.0000 - loss: 0.0362 - val_accuracy: 1.0000 - val_loss: 0.0328 - learning_rate: 2.0000e-04
# Epoch 67/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 360ms/step - accuracy: 1.0000 - loss: 0.0310 - val_accuracy: 1.0000 - val_loss: 0.0312 - learning_rate: 2.0000e-04
# Epoch 68/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 302ms/step - accuracy: 1.0000 - loss: 0.0319 - val_accuracy: 1.0000 - val_loss: 0.0305 - learning_rate: 2.0000e-04
# Epoch 69/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 327ms/step - accuracy: 1.0000 - loss: 0.0308 - val_accuracy: 1.0000 - val_loss: 0.0298 - learning_rate: 2.0000e-04
# Epoch 70/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 301ms/step - accuracy: 1.0000 - loss: 0.0272 - val_accuracy: 1.0000 - val_loss: 0.0291 - learning_rate: 2.0000e-04
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 1.0000 - loss: 0.0302
# Test Loss: 0.029092207551002502
# Test Accuracy: 100.00%
